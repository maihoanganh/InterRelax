# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_AMGM()
# Out:
# ***Problem setting***
# Number of variables: n=3
# Number of inequality constraints: m=
# WARNING: replacing module InterRelax.
# 2
# Number of equality constraints: l=0
#
# -------------------------------
#
# **Interrupted relaxation based on Putinar-Vasilescu's Positivstellensatz**
# Relaxation order: k=0
# Sparsity order: s=1
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# ...

# %%
data="/home/hoanganh/Desktop/math-topics/InterruptedRelax/codes/dataPOP2"
# Out:
# "/home/hoanganh/Desktop/math-topics/InterruptedRelax/codes/dataPOP2"

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_dense_POP_arbcons(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=20
# Number of inequality constraints: m=2
# Number of equality constraints: l=0
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 21
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [20]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 231 affine constraints.
# SDP assembling time: 0.00055444 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 231
#   Cones                  : 0
#   Scalar variables       : 22
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_CS_POP_arbcons(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=1000
# Number of inequality constraints: m=201
# Number of equality constraints: l=0
# Clique parameter: u=10
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# Maximal matrix size: 12
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# WARNING: replacing module InterRelax.
# InterruptException:
#
# Stacktrace:
#  [1] (::DynamicPolynomials.var"#50#52"{DynamicPolynomials.Monomial{true},typeof(+),Array{Array{Int64,1},1}})(::Array{Int64,1}) at /home/hoanganh/.julia/packages/DynamicPolynomials/5p8Ga/src/cmult.jl:83
#  [2] mapexponents(::Function, ::DynamicPolynomials.Monomial{true}, ::DynamicPolynomials.Monomial{true}) at /home/hoanganh/.julia/packages/DynamicPolynomials/5p8Ga/src/cmult.jl:109
#  [3] * at /home/hoanganh/.julia/packages/MultivariatePolynomials/vqcb5/src/operators.jl:271 [inlined]
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_PMSV(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=16
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 17
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [16]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 153 affine constraints.
# SDP assembling time: 0.000373844 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 153
#   Cones                  : 0
#   Scalar variables       : 18
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_compute_stability_number_of_graph_random(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=10
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 11
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [10]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 66 affine constraints.
# SDP assembling time: 0.000194623 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 66
#   Cones                  : 0
#   Scalar variables       : 12
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_compute_stability_number_of_graph(data)
# Out:
# Ordinal number of POP: Pb=GD02_a
# ***Problem setting***
# Number of variables: n=23
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 24
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [23]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 300 affine constraints.
# SDP assembling time: 0.000697805 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 300
#   Cones                  : 0
#   Scalar variables       : 25
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_deciding_copositivity(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=10
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 11
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [10]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 66 affine constraints.
# SDP assembling time: 0.000199014 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 66
#   Cones                  : 0
#   Scalar variables       : 12
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_deciding_nonegativity(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=5
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=2
# Maximal matrix size: 21
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [5]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 126 affine constraints.
# SDP assembling time: 0.000825633 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 126
#   Cones                  : 0
#   Scalar variables       : 22
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_dense_POP_binary_constr_random(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=10
# Number of inequality constraints: m=1
# Number of equality constraints: l=10
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 11
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [10]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 66 affine constraints.
# SDP assembling time: 0.000202376 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 66
#   Cones                  : 0
#   Scalar variables       : 21
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_CertifyNN(data)
# Out:
# Ordinal number of POP: i=1
# ***Problem setting***
# Number of variables: n=174
# Number of inequality constraints: m=175
# Number of equality constraints: l=87
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# Maximal matrix size: 89
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [88]
# [87]
# ------------------------------------------------------
# Obtained the variable cliques in 0.252544191 seconds. The maximal size of cliques is 88.
# Assembling the SDP...
# There are 11659 affine constraints.
# SDP assembling time: 0.361488471 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test()
# Out:
# ***Problem setting***
# Number of variables: n=2
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=2
# Maximal matrix size: 6
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [2]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 15 affine constraints.
# SDP assembling time: 0.000138458 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 15
#   Cones                  : 0
#   Scalar variables       : 7
#   Matrix variables       : 4
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# ...

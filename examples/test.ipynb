# %%
data="/home/hoanganh/Desktop/math-topics/InterruptedRelax/codes/dataPOP2"
# Out:
# "/home/hoanganh/Desktop/math-topics/InterruptedRelax/codes/dataPOP2"

# %%
using DynamicPolynomials

@polyvar x[1:2] # nonnegative variables

f=x[1]^2+0.5*x[1]*x[2]-0.25*x[2]^2+0.75*x[1]-0.3*x[2] # the objective polynomial to minimize

g=[1.0-sum(x.^2)] # the inequality constraints
h=[(x[1]-1.0)*x[2]] # the equality constraints

k=1 # relaxation order
s=3 # sparsity order

include("../src/InterRelax.jl")
using .InterRelax

# get information from the input data f,gi,hj
n,m,l,lmon_g,supp_g,coe_g,lmon_h,supp_h,coe_h,lmon_f,supp_f,coe_f,dg,dh=InterRelax.get_info(x,f,g,h,sparse=false);

# get an approximate optimal value and an approximate optimal solution of the polynomial optimization problem
    opt_val,opt_sol=InterRelax.RelaxDense(n,m,l,
                                          lmon_g,supp_g,coe_g, # information of the inequality constraints
                                          lmon_h,supp_h,coe_h, # information of the equality constraints
                                          lmon_f,supp_f,coe_f, # information of the objective polynomial
                                          dg,dh,k,s,
                                          solver="Mosek", # solver for the semidefinite program
                                          comp_opt_sol=true) # to
# Out:
# **Interrupted relaxation based on Polya's Positivstellensatz**
# Relaxation order: k=1
# Factor width upper bound: s=3
# Maximal matrix size:3
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 8
#   Matrix variables       : 3
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test()
# Out:
# ***Problem setting***
# Number of variables: n=2
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Dense case:
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# WARNING: replacing module InterRelax.
# Relaxation order: k=2
# Maximal matrix size: 6
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [2]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 15 affine constraints.
# SDP assembling time: 0.213846014 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 15
#   Cones                  : 0
#   Scalar variables       : 7
#   Matrix variables       : 4
#   Integer variables      : 0
#
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_AMGM()

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_dense_POP_arbcons(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=20
# Number of inequality constraints: m=2
# Number of equality constraints: l=0
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 21
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [20]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 231 affine constraints.
# SDP assembling time: 0.00055444 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 231
#   Cones                  : 0
#   Scalar variables       : 22
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_CS_POP_arbcons(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=1000
# Number of inequality constraints: m=201
# Number of equality constraints: l=0
# Clique parameter: u=10
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# Maximal matrix size: 12
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# WARNING: replacing module InterRelax.
# InterruptException:
#
# Stacktrace:
#  [1] (::DynamicPolynomials.var"#50#52"{DynamicPolynomials.Monomial{true},typeof(+),Array{Array{Int64,1},1}})(::Array{Int64,1}) at /home/hoanganh/.julia/packages/DynamicPolynomials/5p8Ga/src/cmult.jl:83
#  [2] mapexponents(::Function, ::DynamicPolynomials.Monomial{true}, ::DynamicPolynomials.Monomial{true}) at /home/hoanganh/.julia/packages/DynamicPolynomials/5p8Ga/src/cmult.jl:109
#  [3] * at /home/hoanganh/.julia/packages/MultivariatePolynomials/vqcb5/src/operators.jl:271 [inlined]
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_PMSV(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=16
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 17
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [16]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 153 affine constraints.
# SDP assembling time: 0.000373844 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 153
#   Cones                  : 0
#   Scalar variables       : 18
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_compute_stability_number_of_graph_random(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=10
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 11
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [10]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 66 affine constraints.
# SDP assembling time: 0.000194623 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 66
#   Cones                  : 0
#   Scalar variables       : 12
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_compute_stability_number_of_graph(data)
# Out:
# Ordinal number of POP: Pb=GD02_a
# ***Problem setting***
# Number of variables: n=23
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 24
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [23]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 300 affine constraints.
# SDP assembling time: 0.000697805 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 300
#   Cones                  : 0
#   Scalar variables       : 25
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_compute_stability_number_of_graph_ball_constr(data)
# Out:
# Ordinal number of POP: Pb=GD02_a
# ***Problem setting***
# Number of variables: n=23
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 24
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [23]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 300 affine constraints.
# SDP assembling time: 0.000596572 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 300
#   Cones                  : 0
#   Scalar variables       : 25
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_deciding_copositivity(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=10
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 11
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [10]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 66 affine constraints.
# SDP assembling time: 0.000199014 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 66
#   Cones                  : 0
#   Scalar variables       : 12
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_deciding_nonegativity(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=5
# Number of inequality constraints: m=1
# Number of equality constraints: l=1
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=2
# Maximal matrix size: 21
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [5]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 126 affine constraints.
# SDP assembling time: 0.000825633 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 126
#   Cones                  : 0
#   Scalar variables       : 22
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_dense_POP_binary_constr_random(data)
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# Number of variables: n=10
# Number of inequality constraints: m=1
# Number of equality constraints: l=10
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 11
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [10]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 66 affine constraints.
# SDP assembling time: 0.000202376 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 66
#   Cones                  : 0
#   Scalar variables       : 21
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_MAXCUT(data)
# Out:
# Ordinal number of POP: Pb=burma14
# ***Problem setting***
# Number of variables: n=14
# Number of inequality constraints: m=1
# Number of equality constraints: l=14
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# Maximal matrix size: 15
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [14]
# [1]
# ------------------------------------------------------
# Assembling the SDP...
# There are 120 affine constraints.
# SDP assembling time: 0.000471266 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 120
#   Cones                  : 0
#   Scalar variables       : 29
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_CertifyNNHousing(data)
# Out:
# Ordinal number of POP: y=1
# ***Problem setting***
# Number of variables: n=27
# Number of inequality constraints: m=28
# Number of equality constraints: l=14
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# Maximal matrix size: 9
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [8]
# [20]
# ------------------------------------------------------
# Obtained the variable cliques in 0.000434989 seconds. The maximal size of cliques is 8.
# Assembling the SDP...
# There are 216 affine constraints.
# SDP assembling time: 0.001254355 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_CertifyNNDigits(data)
# Out:
# Ordinal number of POP: y=1
# ***Problem setting***
# Number of variables: n=84
# Number of inequality constraints: m=85
# Number of equality constraints: l=20
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# Maximal matrix size: 12
# WARNING: replacing module InterRelax.
# **Semidefinite relaxation based on Putinar's Positivstellensatz**
# Relaxation order: k=1
# ************************TSSOS************************
# TSSOS is launching...
# ------------------------------------------------------
# The clique sizes of varibles:
# [11]
# [74]
# ------------------------------------------------------
# Obtained the variable cliques in 0.00181232 seconds. The maximal size of cliques is 11.
# Assembling the SDP...
# There are 954 affine constraints.
# SDP assembling time: 0.007190163 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
# ...

# %%
include("../src/InterRelax.jl")
using .InterRelax

InterRelax.test_compare_with_sign_sym()
# Out:
# Ordinal number of POP: Pb=1
# ***Problem setting***
# WARNING: replacing module InterRelax.
# Number of variables: n=100
# Number of inequality constraints: m=2
# Number of equality constraints: l=0
#
# -------------------------------
#
# Ordinal number of SDP: Id=1
#
# -------------------------------
#
# ***************************TSSOS***************************
# TSSOS is launching...
# Starting to compute the block structure...
# ------------------------------------------------------
# The sizes of PSD blocks:
# [101, 1]
# [1, 5050]
# ------------------------------------------------------
# Obtained the block structure in 49.211048326 seconds. The maximal size of blocks is 101.
# Assembling the SDP...
# There are 5151 affine constraints.
# SDP assembling time: 0.684019334 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 5151
# ...

# %%
using DynamicPolynomials

println("***Problem setting***")

n=3

println("Number of variables: n=",n)

@polyvar x[1:n]# variables

f=sum(x)+0.0

g=[prod(x)-1.0; 3.0-sum(x)]

m=length(g)
println("Number of inequality constraints: m=",m)

l=0

h=Vector{Polynomial{true,Float64}}(undef,l)

l=length(h)
println("Number of equality constraints: l=",l)
# Out:
# ***Problem setting***
# Number of variables: n=3
# Number of inequality constraints: m=2
# Number of equality constraints: l=0

# %%
include("../src/InterRelax.jl")
using .InterRelax

k=20
s=1

n,m,l,lmon_g,supp_g,coe_g,lmon_h,supp_h,coe_h,lmon_f,supp_f,coe_f,dg,dh=InterRelax.get_info(x,f,g,h,sparse=false);

println("Relaxation order: k=",k)
println("Sparsity order: s=",s)

@time opt_val1=InterRelax.RelaxDense(n,m,l,lmon_g,supp_g,coe_g,lmon_h,supp_h,coe_h,
    lmon_f,supp_f,coe_f,dg,dh,k,s,solver="Mosek")
# Out:
# Relaxation order: k=20
# Sparsity order: s=1
# WARNING: replacing module InterRelax.
# **Interrupted relaxation based on Putinar-Vasilescu's Positivstellensatz**
# Relaxation order: k=20
# Sparsity order: s=1
# Maximal matrix size:1
# MOSEK warning 52: A numerically large lower bound value  1.3e+08 is specified for constraint '' (107).
# MOSEK warning 53: A numerically large upper bound value  1.3e+08 is specified for constraint '' (107).
# MOSEK warning 52: A numerically large lower bound value  1.6e+08 is specified for constraint '' (108).
# MOSEK warning 53: A numerically large upper bound value  1.6e+08 is specified for constraint '' (108).
# MOSEK warning 52: A numerically large lower bound value  1.6e+08 is specified for constraint '' (109).
# MOSEK warning 53: A numerically large upper bound value  1.6e+08 is specified for constraint '' (109).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (110).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (110).
# MOSEK warning 52: A numerically large lower bound value  1.6e+08 is specified for constraint '' (123).
# MOSEK warning 53: A numerically large upper bound value  1.6e+08 is specified for constraint '' (123).
# MOSEK warning 52: A numerically large lower bound value  2.2e+08 is specified for constraint '' (124).
# MOSEK warning 53: A numerically large upper bound value  2.2e+08 is specified for constraint '' (124).
# MOSEK warning 52: A numerically large lower bound value  2.3e+08 is specified for constraint '' (125).
# MOSEK warning 53: A numerically large upper bound value  2.3e+08 is specified for constraint '' (125).
# MOSEK warning 52: A numerically large lower bound value  1.9e+08 is specified for constraint '' (126).
# MOSEK warning 53: A numerically large upper bound value  1.9e+08 is specified for constraint '' (126).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (127).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (127).
# MOSEK warning 52: A numerically large lower bound value  1.3e+08 is specified for constraint '' (138).
# MOSEK warning 53: A numerically large upper bound value  1.3e+08 is specified for constraint '' (138).
# Warning number 52 is disabled.
# Warning number 53 is disabled.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2024
#   Cones                  : 0
#   Scalar variables       : 5126
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# GP based matrix reordering started.
# GP based matrix reordering terminated.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2024
#   Cones                  : 0
#   Scalar variables       : 5126
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1495
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 3446              conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.03              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.02
# Factor     - nonzeros before factor : 1.02e+04          after factor           : 6.12e+04
# Factor     - dense dim.             : 1                 flops                  : 3.86e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.9e+10  1.0e+03  1.2e+03  0.00e+00   1.106291401e+00   1.333333333e+00   1.0e+06  0.04
# 1   1.6e+09  8.2e+01  5.5e+01  -1.00e+00  -6.436970808e+00  -1.770570571e+01  8.2e+04  0.04
# 2   8.2e+05  4.2e-02  1.3e+00  -1.00e+00  -1.569692012e+04  -3.636619269e+04  4.2e+01  0.05
# 3   1.3e+03  6.5e-05  2.1e-03  -1.00e+00  -1.569854267e+08  -3.677659255e+08  6.5e-02  0.05
# 4   6.1e+01  3.1e-06  9.9e-05  -5.51e+00  -1.887275824e+07  -4.195930196e+07  3.1e-03  0.05
# 5   2.6e+01  1.3e-06  4.2e-05  2.59e+00   -3.231697818e+06  -3.273182038e+06  1.3e-03  0.06
# 6   1.2e+01  6.0e-07  1.9e-05  2.21e+01   -1.449274356e+04  -4.477415102e+04  6.0e-04  0.06
# 7   1.1e+00  5.7e-08  1.8e-06  1.13e+00   -1.872392970e+03  -4.373332852e+03  5.7e-05  0.06
# 8   2.0e-01  1.1e-08  3.3e-07  9.88e-01   -3.908823813e+02  -8.580054033e+02  1.1e-05  0.07
# 9   4.1e-02  2.1e-09  6.7e-08  9.31e-01   -6.450764737e+01  -1.701888700e+02  2.1e-06  0.07
# 10  1.0e-02  5.2e-10  1.6e-08  9.11e-01   -2.238622385e+01  -4.574128597e+01  5.2e-07  0.08
# 11  3.9e-03  2.0e-10  6.3e-09  1.09e+00   -8.141562185e+00  -1.601235332e+01  2.0e-07  0.08
# 12  1.4e-03  7.0e-11  2.2e-09  1.13e+00   -1.997324097e+00  -4.128438018e+00  7.0e-08  0.08
# 13  7.1e-04  3.7e-11  1.2e-09  1.23e+00   -1.628704248e-01  -1.092454000e+00  3.7e-08  0.09
# 14  2.9e-04  1.5e-11  4.7e-10  1.16e+00   7.585749018e-01   4.309714363e-01   1.5e-08  0.09
# 15  3.9e-05  2.0e-12  6.4e-11  1.04e+00   8.725205360e-01   8.334313657e-01   2.0e-09  0.09
# 16  3.5e-06  1.8e-13  5.7e-12  9.82e-01   8.993542569e-01   8.964682109e-01   1.8e-10  0.10
# 17  1.5e-09  4.9e-17  1.5e-15  9.99e-01   9.090895277e-01   9.090888802e-01   4.9e-14  0.10
# 18  6.4e-10  1.8e-18  1.1e-18  1.00e+00   9.090909090e-01   9.090909089e-01   4.9e-18  0.11
# Basis identification started.
# Primal basis identification phase started.
# Primal basis identification phase terminated. Time: 0.02
# Dual basis identification phase started.
# Dual basis identification phase terminated. Time: 0.00
# Simplex reoptimization started.
# Primal simplex reoptimization started.
# ITER      DEGITER(%)  PFEAS       DFEAS       POBJ                  DOBJ                  TIME
# 0         0.00        0.00e+00    NA          9.090909090909e-01    NA                    0.00
# 1         50.00       0.00e+00    NA          9.090909090909e-01    NA                    0.00
# Primal simplex reoptimization terminated. Time: 0.00
# Simplex reoptimization terminated. Time: 0.01
# Basis identification terminated. Time: 0.07
# Optimizer terminated. Time: 0.17
#
# Termination status = OPTIMAL
# Optimal value = 0.909090909090909
#   2.383205 seconds (3.99 M allocations: 270.625 MiB, 3.98% gc time)
# (0.909090909090909, Float64[])

# %%
include("../src/InterRelax.jl")
using .InterRelax


for k in 0:20
    for s in 1:8

        n,m,l,lmon_g,supp_g,coe_g,lmon_h,supp_h,coe_h,lmon_f,supp_f,coe_f,dg,dh=InterRelax.get_info(x,f,g,h,sparse=false);

        println("Relaxation order: k=",k)
        println("Sparsity order: s=",s)

        @time opt_val1=InterRelax.RelaxDense(n,m,l,lmon_g,supp_g,coe_g,lmon_h,supp_h,coe_h,
            lmon_f,supp_f,coe_f,dg,dh,k,s,solver="Mosek")

        println("-------------------------")
    end
end
# Out:
# Relaxation order: k=0
# Block size: s=1
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.232334 seconds (179.10 k allocations: 9.014 MiB, 13.47% gc time)
# ==============================
# Relaxation order: k=0
# Block size: s=2
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.003312 seconds (3.68 k allocations: 249.031 KiB)
# ==============================
# Relaxation order: k=0
# Block size: s=3
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.003600 seconds (3.68 k allocations: 248.906 KiB)
# ==============================
# Relaxation order: k=0
# Block size: s=4
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.003400 seconds (3.68 k allocations: 245.906 KiB)
# ==============================
# Relaxation order: k=0
# Block size: s=5
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.003248 seconds (3.68 k allocations: 245.906 KiB)
# ==============================
# Relaxation order: k=0
# Block size: s=6
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.002930 seconds (3.68 k allocations: 251.906 KiB)
# ==============================
# Relaxation order: k=0
# Block size: s=7
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.002812 seconds (3.68 k allocations: 245.906 KiB)
# ==============================
# Relaxation order: k=0
# Block size: s=8
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 4
#   Cones                  : 0
#   Scalar variables       : 6
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.002778 seconds (3.68 k allocations: 245.906 KiB)
# ==============================
# Relaxation order: k=1
# Block size: s=1
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 15
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 0.0
#   0.107202 seconds (46.41 k allocations: 2.397 MiB)
# ==============================
# Relaxation order: k=1
# Block size: s=2
# Maximal matrix size:2
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 3
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 1
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 3
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 8
# Optimizer  - Cones                  : 3
# Optimizer  - Scalar variables       : 18                conic                  : 9
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 29                after factor           : 33
# Factor     - dense dim.             : 0                 flops                  : 3.21e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  4.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   1.8e-01  7.2e-01  5.8e-02  1.18e+00   3.125868683e-01   3.657707957e-01   1.8e-01  0.00
# 2   6.3e-02  2.5e-01  1.2e-02  1.19e+00   6.298971262e-02   7.673334405e-02   6.3e-02  0.00
# 3   5.8e-04  2.3e-03  1.1e-05  1.07e+00   1.043258085e-03   1.119318507e-03   5.8e-04  0.00
# 4   4.5e-06  1.8e-05  7.7e-09  1.00e+00   5.657925161e-06   6.242590522e-06   4.5e-06  0.00
# 5   1.6e-07  6.6e-07  5.4e-11  1.00e+00   1.767138036e-07   1.995871229e-07   1.6e-07  0.00
# 6   2.0e-09  7.8e-09  6.9e-14  1.00e+00   1.893300677e-09   2.179294269e-09   2.0e-09  0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 1.8933007384092093e-9
#   0.005766 seconds (6.26 k allocations: 427.406 KiB)
# ==============================
# Relaxation order: k=1
# Block size: s=3
# Maximal matrix size:3
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 1
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 10                conic                  : 0
# Optimizer  - Semi-definite variables: 2                 scalarized             : 12
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 45                after factor           : 45
# Factor     - dense dim.             : 0                 flops                  : 6.99e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.0e
.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = -3.61177688183897e-9
#   0.010012 seconds (6.36 k allocations: 475.141 KiB)
# ==============================
# Relaxation order: k=1
# Block size: s=6
# Maximal matrix size:4
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 10
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 12                conic                  : 2
# Optimizer  - Semi-definite variables: 1                 scalarized             : 10
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 55                after factor           : 55
# Factor     - dense dim.             : 0                 flops                  : 9.14e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   5.6e-01  2.8e-01  1.5e-01  5.44e-01   -3.011507440e-01  -2.862239038e-01  2.8e-01  0.00
# 2   1.9e-01  9.3e-02  2.7e-02  1.49e+00   1.789401668e-01   1.799760506e-01   9.3e-02  0.00
# 3   4.6e-02  2.3e-02  3.3e-03  1.05e+00   1.785008709e-02   1.814838371e-02   2.3e-02  0.00
# 4   9.8e-03  4.9e-03  3.2e-04  1.06e+00   9.146286727e-03   9.388088220e-03   4.9e-03  0.00
# 5   8.0e-05  4.0e-05  2.3e-07  1.01e+00   4.572562789e-05   4.861673724e-05   4.0e-05  0.00
# 6   1.4e-06  7.1e-07  5.5e-10  9.97e-01   -2.591473361e-07  -2.376823959e-07  7.1e-07  0.00
# 7   1.3e-07  6.6e-08  1.6e-11  9.85e-01   -6.719506787e-08  -6.674365121e-08  6.6e-08  0.00
# 8   5.4e-09  2.7e-09  1.3e-13  9.95e-01   -3.611776882e-09  -3.630172214e-09  2.7e-09  0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = -3.61177688183897e-9
#   0.007009 seconds (6.20 k allocations: 425.016 KiB)
# ==============================
# Relaxation order: k=1
# Block size: s=7
# Maximal matrix size:4
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 10
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 12                conic                  : 2
# Optimizer  - Semi-definite variables: 1                 scalarized             : 10
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 55                after factor           : 55
# Factor     - dense dim.             : 0                 flops                  : 9.14e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   5.6e-01  2.8e-01  1.5e-01  5.44e-01   -3.011507440e-01  -2.862239038e-01  2.8e-01  0.00
# 2   1.9e-01  9.3e-02  2.7e-02  1.49e+00   1.789401668e-01   1.799760506e-01   9.3e-02  0.00
# 3   4.6e-02  2.3e-02  3.3e-03  1.05e+00   1.785008709e-02   1.814838371e-02   2.3e-02  0.00
# 4   9.8e-03  4.9e-03  3.2e-04  1.06e+00   9.146286727e-03   9.388088220e-03   4.9e-03  0.00
# 5   8.0e-05  4.0e-05  2.3e-07  1.01e+00   4.572562789e-05   4.861673724e-05   4.0e-05  0.00
# 6   1.4e-06  7.1e-07  5.5e-10  9.97e-01   -2.591473361e-07  -2.376823959e-07  7.1e-07  0.00
# 7   1.3e-07  6.6e-08  1.6e-11  9.85e-01   -6.719506787e-08  -6.674365121e-08  6.6e-08  0.00
# 8   5.4e-09  2.7e-09  1.3e-13  9.95e-01   -3.611776882e-09  -3.630172214e-09  2.7e-09  0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = -3.61177688183897e-9
#   0.007427 seconds (6.20 k allocations: 420.188 KiB)
# ==============================
# Relaxation order: k=1
# Block size: s=8
# Maximal matrix size:4
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 10
#   Cones                  : 0
#   Scalar variables       : 11
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 10
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 12                conic                  : 2
# Optimizer  - Semi-definite variables: 1                 scalarized             : 10
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 55                after factor           : 55
# Factor     - dense dim.             : 0                 flops                  : 9.14e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   5.6e-01  2.8e-01  1.5e-01  5.44e-01   -3.011507440e-01  -2.862239038e-01  2.8e-01  0.00
# 2   1.9e-01  9.3e-02  2.7e-02  1.49e+00   1.789401668e-01   1.799760506e-01   9.3e-02  0.00
# 3   4.6e-02  2.3e-02  3.3e-03  1.05e+00   1.785008709e-02   1.814838371e-02   2.3e-02  0.00
# 4   9.8e-03  4.9e-03  3.2e-04  1.06e+00   9.146286727e-03   9.388088220e-03   4.9e-03  0.00
# 5   8.0e-05  4.0e-05  2.3e-07  1.01e+00   4.572562789e-05   4.861673724e-05   4.0e-05  0.00
# 6   1.4e-06  7.1e-07  5.5e-10  9.97e-01   -2.591473361e-07  -2.376823959e-07  7.1e-07  0.00
# 7   1.3e-07  6.6e-08  1.6e-11  9.85e-01   -6.719506787e-08  -6.674365121e-08  6.6e-08  0.00
# 8   5.4e-09  2.7e-09  1.3e-13  9.95e-01   -3.611776882e-09  -3.630172214e-09  2.7e-09  0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = -3.61177688183897e-9
#   0.008636 seconds (6.36 k allocations: 483.688 KiB)
# ==============================
# Relaxation order: k=2
# Block size: s=1
# Maximal matrix size:1
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 32
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 1
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 32
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 9
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 19                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 38                after factor           : 42
# Factor     - dense dim.             : 0                 flops                  : 4.44e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.6e+01  2.7e+01  1.3e+01  0.00e+00   2.000000000e+00   -3.000000000e+00  1.0e+01  0.00
# 1   2.3e+00  3.9e+00  1.9e+00  -6.85e-01  -1.773758720e-01  -4.108267989e+00  1.5e+00  0.00
# 2   8.4e-01  1.4e+00  6.7e-01  1.56e+00   4.358219874e-01   -2.594673260e-01  5.4e-01  0.00
# 3   5.6e-01  9.5e-01  4.5e-01  1.85e+00   9.064598902e-01   6.418183899e-01   3.7e-01  0.00
# 4   1.5e-01  2.5e-01  1.2e-01  1.51e+00   1.401112871e+00   1.348048160e+00   9.7e-02  0.00
# 5   3.2e-03  5.4e-03  2.6e-03  1.18e+00   1.444074901e+00   1.442956693e+00   2.1e-03  0.00
# 6   3.2e-07  5.5e-07  2.6e-07  1.00e+00   1.444444407e+00   1.444444294e+00   2.1e-07  0.00
# 7   3.3e-11  5.5e-11  2.6e-11  1.00e+00   1.444444444e+00   1.444444444e+00   2.1e-11  0.00
# Basis identification started.
# Primal basis identification phase started.
# Primal basis identification phase terminated. Time: 0.00
# Dual basis identification phase started.
# Dual basis identification phase terminated. Time: 0.00
# Basis identification terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 1.4444444444407196
#   0.005360 seconds (8.09 k allocations: 600.078 KiB)
# ==============================
# Relaxation order: k=2
# Block size: s=2
# Maximal matrix size:2
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 12
#   Matrix variables       : 15
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 12
#   Matrix variables       : 15
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 20
# Optimizer  - Cones                  : 16
# Optimizer  - Scalar variables       : 58                conic                  : 47
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 158               after factor           : 170
# Factor     - dense dim.             : 0                 flops                  : 3.01e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   3.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1
# 27  8.4e-12  1.2e-12  2.0e-14  1.94e-01   2.977696542e+00   2.977402034e+00   1.2e-12  0.01
# 28  3.3e-12  4.1e-13  6.3e-15  2.48e-01   2.980511456e+00   2.980277531e+00   4.1e-13  0.01
# 29  1.4e-12  1.3e-13  2.0e-15  1.43e-01   2.983289348e+00   2.983055658e+00   1.3e-13  0.01
# 30  1.2e-12  1.3e-13  1.9e-15  2.40e-01   2.983383364e+00   2.983151385e+00   1.3e-13  0.01
# 31  8.0e-13  3.9e-14  5.4e-16  2.33e-01   2.985779379e+00   2.985592112e+00   3.9e-14  0.01
# 32  8.0e-13  3.9e-14  5.4e-16  2.37e-01   2.985779379e+00   2.985592112e+00   3.9e-14  0.01
# 33  8.0e-13  3.9e-14  5.4e-16  2.37e-01   2.985779379e+00   2.985592112e+00   3.9e-14  0.01
# Optimizer terminated. Time: 0.01
#
# Termination status = SLOW_PROGRESS
# Optimal value = 2.9857793788868126
#   0.018358 seconds (12.28 k allocations: 963.000 KiB)
# ==============================
# Relaxation order: k=2
# Block size: s=3
# Maximal matrix size:3
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 12
#   Matrix variables       : 10
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 12
#   Matrix variables       : 10
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 20
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 13                conic                  : 2
# Optimizer  - Semi-definite variables: 10                scalarized             : 60
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 198               after factor           : 210
# Factor     - dense dim.             : 0                 flops                  : 6.23e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   1.4e+00  2.3e-01  1.6e-01  3.71e-02   -1.076531030e+00  -1.220142818e+00  2.3e-01  0.00
# 2   6.3e-01  1.0e-01  4.1e-02  2.13e+00   4.639046326e-01   4.134191697e-01   1.0e-01  0.00
# 3   2.4e-01  4.1e-02  1.5e-02  7.93e-01   1.360741645e+00   1.289488076e+00   4.1e-02  0.00
# 4   1.0e-01  1.7e-02  5.3e-03  3.70e-01   2.001718384e+00   1.933003684e+00   1.7e-02  0.00
# 5   2.1e-02  3.5e-03  6.9e-04  3.89e-01   2.759722190e+00   2.729526454e+00   3.5e-03  0.00
# 6   4.7e-04  7.8e-05  2.6e-06  8.69e-01   2.994511973e+00   2.993661906e+00   7.8e-05  0.00
# 7   5.3e-06  8.8e-07  2.7e-09  1.01e+00   2.999915459e+00   2.999908407e+00   8.8e-07  0.00
# 8   4.8e-07  8.0e-08  7.1e-11  1.04e+00   2.999992036e+00   2.999991471e+00   8.0e-08  0.00
# 9   2.8e-08  4.6e-09  9.6e-13  1.01e+00   2.999999532e+00   2.999999501e+00   4.6e-09  0.00
# Optimizer terminated. Time: 0.00
#
# Termination status = OPTIMAL
# Optimal value = 2.9999995318694417
#   0.009859 seconds (11.95 k allocations: 944.969 KiB)
# ==============================
# Relaxation order: k=2
# Block size: s=4
# Maximal matrix size:4
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 12
#   Matrix variables       : 5
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 12
#   Matrix variables       : 5
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 20
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 13                conic                  : 2
# Optimizer  - Semi-definite variables: 5                 scalarized             : 50
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 210               after factor           : 210
# Factor     - dense dim.             : 0                 flops                  : 6.78e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0
# 15  3.6e-11  3.8e-17  2.3e-19  9.91e-01   2.998357131e+00   2.998335578e+00   6.3e-18  3.16
# 16  6.8e-12  7.2e-18  1.5e-20  9.93e-01   2.999681344e+00   2.999678839e+00   1.2e-18  3.35
# 17  6.5e-13  5.8e-19  3.2e-22  9.98e-01   2.999973827e+00   2.999973642e+00   9.6e-20  3.55
# 18  6.3e-13  1.1e-20  2.1e-24  1.00e+00   2.999999040e+00   2.999999034e+00   3.5e-21  3.76
# Optimizer terminated. Time: 3.76
#
# Termination status = OPTIMAL
# Optimal value = 2.9999990404743064
#   4.776987 seconds (13.30 M allocations: 1.137 GiB, 3.59% gc time)
# ==============================
# Relaxation order: k=16
# Block size: s=6
# Maximal matrix size:6
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (519).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (519).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (520).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (520).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (529).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (529).
# MOSEK warning 52: A numerically large lower bound value  1.3e+08 is specified for constraint '' (530).
# MOSEK warning 53: A numerically large upper bound value  1.3e+08 is specified for constraint '' (530).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (539).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (539).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (624).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (624).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (625).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (625).
# MOSEK warning 52: A numerically large lower bound value  1.5e+08 is specified for constraint '' (634).
# MOSEK warning 53: A numerically large upper bound value  1.5e+08 is specified for constraint '' (634).
# MOSEK warning 52: A numerically large lower bound value  1.6e+08 is specified for constraint '' (635).
# MOSEK warning 53: A numerically large upper bound value  1.6e+08 is specified for constraint '' (635).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (636).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (636).
# Warning number 52 is disabled.
# Warning number 53 is disabled.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1140
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 2669
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1140
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 2669
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1140
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2                 conic                  : 2
# Optimizer  - Semi-definite variables: 2669              scalarized             : 56049
# Factor     - setup time             : 0.09              dense det. time        : 0.00
# Factor     - ML order time          : 0.03              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.32e+05          after factor           : 3.03e+05
# Factor     - dense dim.             : 3                 flops                  : 1.08e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   5.7e+06  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.18
# 1   2.5e+06  1.7e+00  1.8e-01  -1.00e+00  -2.045602702e-07  -2.049281906e+00  4.3e-01  0.45
# 2   9.0e+05  4.6e-01  5.2e-02  -1.00e+00  1.155470022e-06   -6.217304747e+00  1.6e-01  0.71
# 3   1.9e+05  9.8e-02  2.4e-02  -1.00e+00  1.727619583e-05   -2.984647251e+01  3.3e-02  1.09
# 4   1.8e+04  8.1e-03  1.1e-02  -1.00e+00  2.418549008e-04   -3.112107266e+02  3.2e-03  1.33
# 5   3.7e+01  4.9e-05  3.1e-04  -1.00e+00  1.127878940e-01   -1.413284744e+05  6.4e-06  1.56
# 6   3.3e-02  4.4e-08  8.1e-07  -8.09e-01  1.175886987e+00   -1.202130648e+06  5.7e-09  1.79
# 7   5.7e-07  7.6e-13  9.4e-14  9.90e-01   1.192070079e+00   -3.309315702e+01  1.0e-13  2.02
# 8   6.5e-08  8.8e-14  3.1e-15  1.06e+00   1.297089695e+00   -1.629845319e+00  1.1e-14  2.25
# 9   2.1e-08  2.9e-14  1.9e-16  1.53e+00   1.955255201e+00   1.853001724e+00   3.7e-15  2.48
# 10  1.4e-08  1.9e-14  8.0e-17  2.38e+00   2.520119010e+00   2.478928334e+00   2.5e-15  2.72
# 11  7.0e-09  9.3e-15  2.3e-17  1.79e+00   2.802786843e+00   2.788915305e+00   1.2e-15  2.95
# 12  2.8e-09  3.7e-15  5.1e-18  1.41e+00   2.911683503e+00   2.907329667e+00   4.8e-16  3.19
# 13  1.6e-09  2.2e-15  2.1e-18  1.15e+00   2.956822584e+00   2.954810019e+00   2.9e-16  3.43
# 14  7.9e-10  1.1e-15  6.2e-19  1.10e+00   2.979982679e+00   2.979185149e+00   1.4e-16  3.66
# 15  2.9e-10  3.9e-16  1.3e-19  1.04e+00   2.992650269e+00   2.992393903e+00   5.1e-17  3.88
# 16  9.5e-11  1.3e-16  2.1e-20  1.01e+00   2.997426800e+00   2.997367694e+00   1.7e-17  4.12
# 17  3.3e-11  4.4e-17  3.5e-21  1.00e+00   2.999054064e+00   2.999040083e+00   5.8e-18  4.36
# 18  4.1e-12  5.4e-18  1.3e-22  1.00e+00   2.999883421e+00   2.999881775e+00   7.0e-19  4.62
# 19  1.0e-12  1.1e-18  1.1e-23  1.00e+00   2.999975599e+00   2.999975276e+00   1.5e-19  4.89
# 20  1.2e-12  2.0e-19  2.1e-24  1.00e+00   2.999995965e+00   2.999995919e+00   2.4e-20  5.14
# 21  5.3e-12  1.1e-19  1.1e-25  1.00e+00   2.999999474e+00   2.999999468e+00   3.1e-21  5.39
# Optimizer terminated. Time: 5.39
#
# Termination status = OPTIMAL
# Optimal value = 2.999999473611098
#   6.642446 seconds (14.31 M allocations: 1.244 GiB, 3.46% gc time)
# ==============================
# Relaxation order: k=16
# Block size: s=7
# Maximal matrix size:7
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (519).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (519).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (520).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (520).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (529).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (529).
# MOSEK warning 52: A numerically large lower bound value  1.3e+08 is specified for constraint '' (530).
# MOSEK warning 53: A numerically large upper bound value  1.3e+08 is specified for constraint '' (530).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (539).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (539).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (624).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (624).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (625).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (625).
# MOSEK warning 52: A numerically large lower bound value  1.5e+08 is specified for constraint '' (634).
# MOSEK warning 53: A numerically large upper bound value  1.5e+08 is specified for constraint '' (634).
# MOSEK warning 52: A numerically large lower bound value  1.6e+08 is specified for constraint '' (635).
# MOSEK warning 53: A numerically large upper bound value  1.6e+08 is specified for constraint '' (635).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (636).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (636).
# Warning number 52 is disabled.
# Warning number 53 is disabled.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1140
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 2645
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1140
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 2645
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1140
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2                 conic                  : 2
# Optimizer  - Semi-definite variables: 2645              scalarized             : 74060
# Factor     - setup time             : 0.12              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.57e+05          after factor           : 3.18e+05
# Factor     - dense dim.             : 3                 flops                  : 1.24e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   5.7e+06  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.25
# 1   2.5e+06  9.0e-01  1.2e+00  -1.00e+00  -2.057768087e-07  -4.663130070e-01  4.4e-01  0.58
# 2   9.8e+05  6.3e-01  8.4e-01  -1.00e+00  1.284811954e-06   -3.783634152e+00  1.7e-01  0.90
# 3   2.4e+05  9.9e-02  4.3e-01  -1.00e+00  1.593060523e-05   -2.128328887e+01  4.3e-02  1.22
# 4   3.7e+04  1.6e-02  1.7e-01  -1.00e+00  1.413610743e-04   -1.519437914e+02  6.5e-03  1.54
# 5   1.3e+02  8.8e-05  1.3e-02  -1.00e+00  3.948698209e-02   -4.115262750e+04  2.3e-05  1.87
# 6   4.1e-02  2.6e-08  2.1e-05  -9.35e-01  1.202585650e+00   -1.132833336e+06  7.1e-09  2.21
# 7   6.3e-08  4.0e-14  3.8e-14  9.90e-01   1.220037617e+00   -8.433606951e-01  1.1e-14  2.57
# 8   2.6e-08  1.6e-14  5.0e-15  1.71e+00   1.973955092e+00   1.754410071e+00   4.5e-15  2.90
# 9   1.7e-08  1.1e-14  1.9e-15  2.30e+00   2.578974047e+00   2.503523979e+00   2.9e-15  3.24
# 10  4.1e-09  2.6e-15  1.5e-16  1.70e+00   2.896428003e+00   2.888593566e+00   7.1e-16  3.59
# 11  1.4e-09  8.9e-16  2.1e-17  1.17e+00   2.972944322e+00   2.971574729e+00   2.4e-16  3.95
# 12  3.9e-10  2.5e-16  2.3e-18  1.05e+00   2.992293201e+00   2.992088669e+00   6.8e-17  4.30
# 13  5.4e-11  3.4e-17  1.1e-19  1.02e+00   2.998922457e+00   2.998899350e+00   9.4e-18  4.75
# 14  3.8e-12  2.3e-18  1.7e-21  1.00e+00   2.999924356e+00   2.999923076e+00   6.3e-19  5.10
# 15  2.6e-12  7.5e-20  1.3e-23  1.00e+00   2.999996942e+00   2.999996897e+00   2.4e-20  5.43
# 16  4.0e-11  1.4e-19  2.1e-25  1.00e+00   2.999999913e+00   2.999999911e+00   6.5e-22  5.77
# Optimizer terminated. Time: 5.78
#
# Termination status = OPTIMAL
# Optimal value = 2.999999912586331
#   7.812432 seconds (15.44 M allocations: 1.362 GiB, 9.35% gc time)
# ==============================
# Relaxation order: k=16
# Block size: s=8
# Maximal matrix size:8
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (519).
# Excessive output truncated after 524367 bytes.
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (519).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (520).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (520).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (529).
# MOSEK warning 53: A numerically large upper bound value  1.2e+08 is specified for constraint '' (529).
# MOSEK warning 52: A numerically large lower bound value  1.3e+08 is specified for constraint '' (530).
# MOSEK warning 53: A numerically large upper bound value  1.3e+08 is specified for constraint '' (530).
# MOSEK warning 52: A numerically large lower bound value  1.1e+08 is specified for constraint '' (539).
# MOSEK warning 53: A numerically large upper bound value  1.1e+08 is specified for constraint '' (539).
# MOSEK warning 52: A numerically large lower bound value  1.2e+08 is specified for constraint '' (624).
# WARNING: replacing module InterRelax.
